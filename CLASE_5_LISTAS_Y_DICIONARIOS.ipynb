# %% [markdown]
# <a href="https://colab.research.google.com/github/svelandia664-sketch/PROGCOM-A/blob/main/CLASE_5_LISTAS_Y_DICIONARIOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#QUIERO SABER CUANTOS DE N ESTUDIANTES SACAN MAS QUE EL PROMEDIO
estudiante= int(input("ingrese la cantidad de estudiantes:"))
suma=0
c=0
for i in range(estudiante):
  nota= float(input("ingrese la nota {i}:"))
  suma+=nota
promedio= suma/estudiante
print(prom)
for i in range(estudiante):
  if nota>promedio:
    c=+1
print(f"{c} estudiantes sacaron mayor nota que el promedio")
# Out:
# ingrese la cantidad de estudiantes:5
# ingrese la nota {i}:2
# ingrese la nota {i}:3
# ingrese la nota {i}:3.1
# ingrese la nota {i}:5.0
# ingrese la nota {i}:2.3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1189/2506513108.py in <cell line: 0>()
#       7   suma+=nota
#       8 promedio= suma/estudiante
# ----> 9 print(prom)
#      10 for i in range(estudiante):
#      11   if nota>promedio:
#
# NameError: name 'prom' is not defined

# %%
#Quiero saber cuántos de n estudiantes sacan más que el promedio
estudiantes=int(input("Ingrese el número de estudiantes: "))
suma=0
c=0
for i in range(estudiantes):
  nota=float(input(f"Ingrese la nota de cada estudiante {i}: "))
  suma+=nota
prom=suma/estudiantes
print(prom)
for i in range(estudiantes):
  if nota>prom:
    c=c+1
print(f"{c} estudiantes sacaron mayor nota que el promedio")
# Out:
# Ingrese el número de estudiantes: 3
# Ingrese la nota de cada estudiante 0: 2
# Ingrese la nota de cada estudiante 1: 3
# Ingrese la nota de cada estudiante 2: 4
# 3.0
# 3 estudiantes sacaron mayor nota que el promedio

# %% [markdown]
# #LISTAS
# Es una coleccion de elementos que cumplen las siguientes caracteisticas.
#
# 1. Mutable
# 2. Es que tiene index
# 3. Sus elementos estan separados por comas
#
# ##CREACION DE LISTAS
# nombre_listas=[]
#
# Existen dos formas de crear una lista:
# 1. Por extension (se nombran uno a uno los elementos)
# 2. Por comprension (se enuncian las caracterisitcas comunes de los elemetos)

# %%
Galleta=["angeles","dinosaurios","diablitos"]
cant_galletas=[2,2,3]

# %% [markdown]
# ##RECORRIENDO ELEMENTOS DE FORMA MANUAL
#
#
#
# ```
# sintaxis
# nombre_lista[posicion de interes[
# ```

# %%
Galleta[2]
# Out:
# 'diablitos'

# %%
cant_galletas[2]
# Out:
# 3

# %% [markdown]
# RECORRIENDO ELEMENTOS DE FORMA AUTOMATICA

# %%
for caja in range (3):
  print(f"{Galleta[caja]}:{cant_galletas[caja]}")
# Out:
# angeles:2
# dinosaurios:2
# diablitos:3

# %%
estudiantes=int(input("Ingrese el número de estudiantes: "))
suma=0
c=0
notas=[]
for i in range(estudiantes):
  nota=float(input(f"Ingrese la nota de cada estudiante {i}: "))
  notas.append(nota) #anexar las notas
  suma+=nota
prom=suma/estudiantes
print(prom)
for i in range(estudiantes):
  if nota[i]>prom:
    c=c+12.5
print(f"{c} estudiantes sacaron mayor nota que el promedio")
# Out:
# Ingrese el número de estudiantes: 3
# Ingrese la nota de cada estudiante 0: 5
# Ingrese la nota de cada estudiante 1: 3
# Ingrese la nota de cada estudiante 2: 4
# 4.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1189/509634341.py in <cell line: 0>()
#      10 print(prom)
#      11 for i in range(estudiantes):
# ---> 12   if nota[i]>prom:
#      13     c=c+12.5
#      14 print(f"{c} estudiantes sacaron mayor nota que el promedio")
#
# TypeError: 'float' object is not subscriptable

# %% [markdown]
# # **EJERCICIOS GRUPO**

# %% [markdown]
# #1.  De una lista de n trabajadores, decir cuantos ganan mas que el promedio y quienes2

# %%
n=int(input("Ingrese el número de trabajadores: "))

nombres=[]
sueldos=[]

for i in range(n):
    nombre = input(f"Ingrese el nombre del trabajador {i+1} :")
    sueldo = float(input(f"Ingrese el sueldo del trabajador {i+1}:" ))

    nombres.append(nombre)
    sueldos.append(sueldo)

suma=sum(sueldos)
prom=suma/n

c=0

print("Trabajadores que ganan más que el promedio:")

for i in range(n):
    if sueldos[i] > prom:
        print(nombres[i])
        c=c + 1

print("Cantidad que ganan más que el promedio:", c)
# Out:
# Ingrese el número de trabajadores: 2
# Ingrese el nombre del trabajador 1 :LUIS
# Ingrese el sueldo del trabajador 1:20000
# Ingrese el nombre del trabajador 2 :JORGE
# Ingrese el sueldo del trabajador 2:10000
# Trabajadores que ganan más que el promedio:
# LUIS
# Cantidad que ganan más que el promedio: 1

# %% [markdown]
# 2. Desarrollar el menú de una tienda empleando listas

# %%
n=int(input("Ingrese el número de productos: "))
productos=[]
precios=[]
for i in range(n):
    producto=input(f"Ingrese el nombre del producto {i+1}: ")
    precio=float(input(f"Ingrese el precio del producto {i+1}: "))

    productos.append(producto)
    precios.append(precio)

print("Lista de productos disponibles:")

for i in range(n):
    print(productos[i], ":", precios[i])

c=0
total=0

m=int(input("Ingrese la cantidad de productos que desea comprar: "))

for i in range(m):
    compra=input(f"Ingrese el nombre del producto a comprar {i+1}: ")

    for j in range(n):
        if compra == productos[j]:
            print("Producto encontrado - Precio:", precios[j])
            total = total + precios[j]
            c = c + 1

print("Cantidad de productos comprados:", c)
print("Total a pagar:", total)
# Out:
# Ingrese el número de productos: 2
# Ingrese el nombre del producto 1: FORRO
# Ingrese el precio del producto 1: 2000
# Ingrese el nombre del producto 2: JARRA
# Ingrese el precio del producto 2: 3000
# Lista de productos disponibles:
# FORRO : 2000.0
# JARRA : 3000.0
# Ingrese la cantidad de productos que desea comprar: 1
# Ingrese el nombre del producto a comprar 1: FORRO
# Producto encontrado - Precio: 2000.0
# Cantidad de productos comprados: 1
# Total a pagar: 2000.0

# %% [markdown]
# 3.

# %%
numeros = []

n_elementos = int(input("¿Cuántos números desea ingresar? "))

print("\n=== INGRESO DE NÚMEROS ===\n")

for i in range(n_elementos):
    num = int(input(f"Ingrese el número {i+1}: "))
    numeros.append(num)

n = int(input("\n¿De qué número desea encontrar los múltiplos? "))

multiplos = [x for x in numeros if x % n == 0]
contador = len(multiplos)

print("\n=== RESULTADO ===\n")

for num in numeros:
    if num % n == 0:
        print(f"✔ {num} - Es múltiplo de {n}")
    else:
        print(f"✘ {num} - No es múltiplo de {n}")

print(f"\nTotal de números ingresados: {len(numeros)}")
print(f"Múltiplos de {n}:            {contador}")
print(f"No múltiplos de {n}:         {len(numeros) - contador}")
# Out:
# ¿Cuántos números desea ingresar? 2
#
# === INGRESO DE NÚMEROS ===
#
# Ingrese el número 1: 23
# Ingrese el número 2: 25
#
# ¿De qué número desea encontrar los múltiplos? 6
#
# === RESULTADO ===
#
# ✘ 23 - No es múltiplo de 6
# ✘ 25 - No es múltiplo de 6
#
# Total de números ingresados: 2
# Múltiplos de 6:            0
# No múltiplos de 6:         2

# %% [markdown]
# 4. Indicar cuantos de n de pacientes han sido vacunados contra el covid. Mencionar fechas de vacunacion.

# %%
pacientes = []
vacunados = []
fechas = []

n = int(input("¿Cuántos pacientes desea registrar? "))

print("\n=== INGRESO DE PACIENTES ===\n")

for i in range(n):
    print(f"Paciente {i+1} ")
    nombre = input("Nombre del paciente: ")
    estado = input("¿Está vacunado? (si/no): ").lower()

    pacientes.append(nombre)

    if estado == "si":
        fecha = input("Fecha de vacunación (DD/MM/AAAA): ")
        vacunados.append(True)
        fechas.append(fecha)
    else:
        vacunados.append(False)
        fechas.append(None)

    print()

contador = 0

print("=== REGISTRO DE VACUNACIÓN COVID ===\n")

for i in range(len(pacientes)):
    if vacunados[i] == True:
        contador += 1
        print(f"✔ {pacientes[i]} - Vacunado el: {fechas[i]}")
    else:
        print(f"✘ {pacientes[i]} - No vacunado")

print(f"\nTotal de pacientes:   {len(pacientes)}")
print(f"Pacientes vacunados:  {contador}")
print(f"Pacientes sin vacunar:{len(pacientes) - contador}")
# Out:
# ¿Cuántos pacientes desea registrar? 2
#
# === INGRESO DE PACIENTES ===
#
# Paciente 1
# Nombre del paciente: Luisa
# ¿Está vacunado? (si/no): si
# Fecha de vacunación (DD/MM/AAAA): 20/3/2002
#
# Paciente 2
# Nombre del paciente: Luis
# ¿Está vacunado? (si/no): no
#
# === REGISTRO DE VACUNACIÓN COVID ===
#
# ✔ Luisa - Vacunado el: 20/3/2002
# ✘ Luis  - No vacunado
#
# Total de pacientes:   2
# Pacientes vacunados:  1
# Pacientes sin vacunar:1
