# %% [markdown]
# <a href="https://colab.research.google.com/github/svelandia664-sketch/PROGCOM-A/blob/main/Clase_10_POO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROGRAMACIÓN ORIENTADA A OBJETOS
# 1. Es un paradigma de programación
# 2. Tienes 4 pilares fundamentales:
# Herencia, polimorfismo, abstracción, encapsulamiento.
# 3. Ventajas
# * Modularidad: Manejar el código por trozos
# * Reusabilidad: Reusar clases y objetos
# * Mantenibilidad: Agregar fácilmente nuevos métodos
# * Escalabilidad: Escalar a nuevas aplicaciones desde un mismo código
# * Seguridad: No todos pueden alterar el código
# 4. A los molde, croquis--> clase
# 5. Lo que produce una clase --> Instancia
# de clase--> Objeto
# 6. Funciones--> Método
# 7. Variables--> Atributos
# 8. Sintaxis
#
#
# ```
# class NombreClase(atributos):
#   #Constructor
#   def __init__(self,p1,p2,p3,...pn):
#     pass
#   def metodo1():
#     pass
#   def metodo2():
#     pass
# ```
# 9. Invocando una clase
#
# ```
# variable=NombreClase()
# ```

# %%
class disfraz():
  #creando el constructor
  def __init__(self,color, talla, forma, material, personaje):
    #Creando atributos de clase
    self.color=color
    self.talla=talla
    self.material=material
    self.personaje=personaje

  def imprimir(self):
    return f"El disfraz es de {self.personaje}.\nEs de talla {self.talla}"

# %%
perro=disfraz("morado","10","cuadrado","plástico","bob esponja")

# %%
print(perro.imprimir())
# Out:
# El disfraz es de bob esponja.
# Es de talla 10

# %%
class Edificio():
  #Construyendo el cosntructor
  def __init__(self,material,ubicacion,fachada,ventanas,puertas,nombre):
    self.material=material
    self.ubicacion=ubicacion
    self.fachada=fachada
    self.ventanas=ventanas
    self.puertas=puertas
    self.nombre=nombre

  def direccion(self,tipo):
    return f"Tipo de edificacion:\nDireccion:{self.ubicacion}"

  def descripcion(self,tipo):
    print(f"{self.nombre} es un {tipo} ubicado en {self.ubicacion}")
    print(f"Tiene {self.ventanas} ventana(s), {self.puertas} puerta(s)")
    print (f"Su fachada es {self.fachada}")

# %%
colegio=Edificio("Ladrillo","Bucaramanga","De colores pasteles con números",4,2,"Los angelitos")
floresteria=Edificio("Ladrillo","Floridablanca","Campestre con césped verde",0,1,"Florecitas")

# %%
colegio.fachada="Colores pasteles, con césped verde y angelitos"

# %%
colegio.descripcion("colegio")
# Out:
# Los angelitos es un colegio ubicado en Bucaramanga
# Tiene 4 ventana(s), 2 puerta(s)
# Su fachada es Colores pasteles, con césped verde y angelitos

# %%
floresteria.descripcion("floresta")
# Out:
# Florecitas es un floresta ubicado en Floridablanca
# Tiene 0 ventana(s), 1 puerta(s)
# Su fachada es Campestre con césped verde
