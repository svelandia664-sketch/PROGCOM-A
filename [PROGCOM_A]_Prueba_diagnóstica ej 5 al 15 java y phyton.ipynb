# %% [markdown]
# <a href="https://colab.research.google.com/github/svelandia664-sketch/PROGCOM-A/blob/main/%5BPROGCOM_A%5D_Prueba_diagn%C3%B3stica%20ej%205%20al%2015%20java%20y%20phyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**EJERCICIOS**
# 5. Crea un programa que resuelva una ecuación cuadrática (ax² + bx + c = 0) pidiendo los valores de a, b y c.
# 6. Desarrolla un programa que determine si un número es par o impar.
# 7. Crea un programa que determine si un año es bisiesto (divisible por 4 y no por 100, o divisible por 400).
# 8. Escribe un programa que solicite el nombre del usuario y determine si una persona pertenece a la tercera edad (70 años o más) y si se cumple la condición, imprima que se le da prioridad en la fila.
# 9. Desarrolla un programa que compare tres números y muestre el mayor.
# 10. Crea un programa que determine si un triángulo es equilátero, isósceles o escaleno según sus lados.
# 11. Escribe un programa que calcule el índice de masa corporal (IMC) y determine la categoría (bajo peso, normal, sobrepeso, obesidad). Al final, el programa debe imprimir: el nombre del usuario, su categoría y una breve descripción de lo que debe hacer de acuerdo a su categoría.
# 12. Desarrolla un programa que simule una calculadora simple (+, -, *, /) con dos números.
# 13. Crea un programa que determine la calificación en letras (A, B, C, D, F) según una nota numérica (0-100).
# 14. Escribe un programa que determine el día de la semana según un número (1-7).
# 15. Desarrolla un programa que valide si tres números pueden formar un triángulo y de qué tipo es.

# %%
#Punto 5 - if else
a = float(input("Valor de a: "))
b = float(input("Valor de b: "))
c = float(input("Valor de c: "))

d = b*b - 4*a*c

if d >= 0:
    print("Tiene solución real")
else:
    print("No tiene solución real")
# Out:
# Valor de a: 1
# Valor de b: 2
# Valor de c: 3
# No tiene solución real

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 5 - if elif else
a = float(input("Valor de a: "))
b = float(input("Valor de b: "))
c = float(input("Valor de c: "))
d = b*b - 4*a*c

if d > 0:
    print("Dos soluciones reales")
elif d == 0:
    print("Una solución real")
else:
    print("No tiene soluciones reales")
# Out:
# Valor de a: 2
# Valor de b: 3
# Valor de c: 1
# Dos soluciones reales

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 5 - Si Ternario
a = float(input("Valor de a: "))
b = float(input("Valor de b: "))
c = float(input("Valor de c: "))

d = b*b - 4*a*c

resultado = "Tiene solución real" if d >= 0 else "No tiene solución real"
print(resultado)
# Out:
# Valor de a: 2
# Valor de b: 4
# Valor de c: 1
# Tiene solución real

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 6 - if  else
n = int(input("Número: "))

if n % 2 == 0:
    print("Par")
else:
    print("Impar")
# Out:
# Número: 2
# Par

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 6 - if elif else
n = int(input("Número: "))

if n % 2 == 0:
    print("Par")
elif n % 2 != 0:
    print("Impar")
else:
    print("Error")
# Out:
# Número: 5
# Impar

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 6 - Si ternario
n = int(input("Número: "))

resultado = "Par" if n % 2 == 0 else "Impar"
print(resultado)
# Out:
# Número: 3
# Impar

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 7 - if else
año = int(input("Año: "))

if (año % 4 == 0 and año % 100 != 0) or año % 400 == 0:
    print("Es bisiesto")
else:
    print("No es bisiesto")
# Out:
# Año: 2024
# Es bisiesto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 7 - if elif else
año = int(input("Año: "))

if año % 400 == 0:
    print("Es bisiesto")
elif año % 100 == 0:
    print("No es bisiesto")
elif año % 4 == 0:
    print("Es bisiesto")
else:
    print("No es bisiesto")
# Out:
# Año: 2026
# No es bisiesto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 7 - Si ternario
año = int(input("Año: "))

resultado = "Es bisiesto" if (año % 4 == 0 and año % 100 != 0) or año % 400 == 0 else "No es bisiesto"
print(resultado)
# Out:
# Año: 2028
# Es bisiesto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 8 - if else
nombre = input("Nombre: ")
edad = int(input("Edad: "))

if edad >= 70:
    print(nombre, "tiene prioridad")
else:
    print(nombre, "no tiene prioridad")
# Out:
# Nombre: Simon
# Edad: 18
# Simon no tiene prioridad

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 8 - if elif else
nombre = input("Nombre: ")
edad = int(input("Edad: "))

if edad > 120:
    print("Edad inválida")
elif edad >= 70:
    print(nombre, "tiene prioridad")
else:
    print(nombre, "no tiene prioridad")
# Out:
# Nombre: Juan
# Edad: 73
# Juan tiene prioridad

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 8 - Si ternario
nombre = input("Nombre: ")
edad = int(input("Edad: "))

resultado = "tiene prioridad" if edad >= 70 else "no tiene prioridad"
print(nombre, resultado)
# Out:
# Nombre: camilo
# Edad: 69
# camilo no tiene prioridad

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 9 - if else
a = int(input("Número 1: "))
b = int(input("Número 2: "))
c = int(input("Número 3: "))

if a > b and a > c:
    print("Mayor:", a)
else:
    if b > c:
        print("Mayor:", b)
    else:
        print("Mayor:", c)
# Out:
# Número 1: 2
# Número 2: 3
# Número 3: 1
# Mayor: 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 9 - if elif else
a = int(input("Número 1: "))
b = int(input("Número 2: "))
c = int(input("Número 3: "))

if a > b and a > c:
    print("Mayor:", a)
elif b > c:
    print("Mayor:", b)
else:
    print("Mayor:", c)
# Out:
# Número 1: 3
# Número 2: 4
# Número 3: 6
# Mayor: 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 9 - Si ternario
a = int(input("Número 1: "))
b = int(input("Número 2: "))
c = int(input("Número 3: "))

mayor = a if a > b and a > c else b if b > c else c
print("Mayor:", mayor)
# Out:
# Número 1: 1
# Número 2: 1
# Número 3: 8
# Mayor: 8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 10 - if else
l1 = int(input("Lado 1: "))
l2 = int(input("Lado 2: "))
l3 = int(input("Lado 3: "))

tipo = "Equilátero" if l1==l2 and l2==l3 else "Isósceles" if l1==l2 or l1==l3 or l2==l3 else "Escaleno"
print(tipo)
# Out:
# Lado 1: 2
# Lado 2: 3
# Lado 3: 2
# Isósceles

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 10 - if elif else
l1 = int(input("Lado 1: "))
l2 = int(input("Lado 2: "))
l3 = int(input("Lado 3: "))

if l1 == l2 and l2 == l3:
    print("Equilátero")
else:
    if l1 == l2 or l1 == l3 or l2 == l3:
        print("Isósceles")
    else:
        print("Escaleno")
# Out:
# Lado 1: 1
# Lado 2: 1
# Lado 3: 1
# Equilátero

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 10 - Si ternario
l1 = int(input("Lado 1: "))
l2 = int(input("Lado 2: "))
l3 = int(input("Lado 3: "))

tipo = "Equilátero" if l1==l2 and l2==l3 else "Isósceles" if l1==l2 or l1==l3 or l2==l3 else "Escaleno"
print(tipo)
# Out:
# Lado 1: 2
# Lado 2: 3
# Lado 3: 4
# Escaleno

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 11 - if else
nombre = input("Nombre: ")
peso = float(input("Peso: "))
altura = float(input("Altura: "))

imc = peso/(altura*altura)

if imc < 25:
    print(nombre, "tiene IMC Normal, debe continuar igual.")
else:
    print(nombre, "tiene Sobrepeso u Obesidad, debe cuidar su alimentacion y hacer gym")
# Out:
# Nombre: carlos
# Peso: 130
# Altura: 1.80
# carlos tiene Sobrepeso u Obesidad, debe cuidar su alimentacion y hacer gym

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 11 - if elif else
nombre = input("Nombre: ")
peso = float(input("Peso: "))
altura = float(input("Altura: "))

imc = peso/(altura*altura)

if imc < 18.5:
    print(nombre, "tiene Bajo peso, debe comer más")
elif imc < 25:
    print(nombre, "está Normal, sigue asi.")
elif imc < 30:
    print(nombre, "tiene Sobrepeso, debe hacer dieta")
else:
    print(nombre, "tiene Obesidad, debe cambiar sus habitos radicalmente.")
# Out:
# Nombre: alex
# Peso: 160
# Altura: 1.90
# alex tiene Obesidad, debe cambiar sus habitos radicalmente.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 11 - Si ternario
nombre = input("Nombre: ")
peso = float(input("Peso: "))
altura = float(input("Altura: "))

imc = peso/(altura*altura)

categoria = "Bajo peso" if imc<18.5 else "Normal" if imc<25 else "Sobrepeso" if imc<30 else "Obesidad"
print(nombre, categoria)
# Out:
# Nombre: Cristian
# Peso: 60
# Altura: 2
# Cristian Bajo peso

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 12 - if else
a = float(input("Número 1: "))
b = float(input("Número 2: "))
op = input("Operación (+,-,*,/): ")

if op == "+":
    print(a+b)
else:
    print("Operación inválida")
# Out:
# Número 1: 1
# Número 2: 1
# Operación (+,-,*,/): +
# 2.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 12 - if elif else
a = float(input("Número 1: "))
b = float(input("Número 2: "))
op = input("Operación (+,-,*,/): ")

if op == "+":
    print(a+b)
elif op == "-":
    print(a-b)
elif op == "*":
    print(a*b)
elif op == "/":
    print(a/b)
else:
    print("Operación inválida")
# Out:
# Número 1: 1
# Número 2: 2
# Operación (+,-,*,/): *
# 2.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 12 - Si ternario
a = float(input("Número 1: "))
b = float(input("Número 2: "))
op = input("Operación (+,-,*,/): ")

resultado = a+b if op=="+" else a-b if op=="-" else a*b if op=="*" else a/b if op=="/" else 0
print(resultado)
# Out:
# Número 1: 2
# Número 2: 4
# Operación (+,-,*,/): /
# 0.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 13 - if else
nota = int(input("Nota: "))

if nota >= 90:
    print("A")
else:
    if nota >= 80:
        print("B")
    else:
        if nota >= 70:
            print("C")
        else:
            if nota >= 60:
                print("D")
            else:
                print("F")
# Out:
# Nota: 86
# B

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 13 - if elif else
nota = int(input("Nota: "))

if nota >= 90:
    print("A")
elif nota >= 80:
    print("B")
elif nota >= 70:
    print("C")
elif nota >= 60:
    print("D")
else:
    print("F")
# Out:
# Nota: 76
# C

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 13 - Si ternario
nota = int(input("Nota: "))

letra = "A" if nota>=90 else "B" if nota>=80 else "C" if nota>=70 else "D" if nota>=60 else "F"
print(letra)
# Out:
# Nota: 30
# F

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 14 - if  else
dia = int(input("Número (1-7): "))

if dia == 1:
    print("Lunes")
else:
    if dia == 2:
        print("Martes")
    else:
        if dia == 3:
            print("Miércoles")
        else:
            if dia == 4:
                print("Jueves")
            else:
                if dia == 5:
                    print("Viernes")
                else:
                    if dia == 6:
                        print("Sábado")
                    else:
                        if dia == 7:
                            print("Domingo")
                        else:
                            print("Inválido")
# Out:
# Número (1-7): 2
# Martes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 14 - if elif else
dia = int(input("Número (1-7): "))

if dia == 1:
    print("Lunes")
elif dia == 2:
    print("Martes")
elif dia == 3:
    print("Miércoles")
elif dia == 4:
    print("Jueves")
elif dia == 5:
    print("Viernes")
elif dia == 6:
    print("Sábado")
elif dia == 7:
    print("Domingo")
else:
    print("Inválido")
# Out:
# Número (1-7): 7
# Domingo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 14 - Si ternario
dia = int(input("Número (1-7): "))

nombre = "Lunes" if dia==1 else "Martes" if dia==2 else "Miércoles" if dia==3 else "Jueves" if dia==4 else "Viernes" if dia==5 else "Sábado" if dia==6 else "Domingo" if dia==7 else "Inválido"
print(nombre)
# Out:
# Número (1-7): 1
# Lunes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 15 - if else
a = int(input("Lado 1: "))
b = int(input("Lado 2: "))
c = int(input("Lado 3: "))

if a + b > c and a + c > b and b + c > a:
    if a == b and b == c:
        print("Sí forman triángulo - Equilátero")
    else:
        if a == b or a == c or b == c:
            print("Sí forman triángulo - Isósceles")
        else:
            print("Sí forman triángulo - Escaleno")
else:
    print("No forman triángulo")
# Out:
# Lado 1: 2
# Lado 2: 2
# Lado 3: 2
# Sí forman triángulo - Equilátero

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 15 - if elif else
a = int(input("Lado 1: "))
b = int(input("Lado 2: "))
c = int(input("Lado 3: "))

if a + b <= c or a + c <= b or b + c <= a:
    print("No forman triángulo")
elif a == b and b == c:
    print("Equilátero")
elif a == b or a == c or b == c:
    print("Isósceles")
else:
    print("Escaleno")
# Out:
# Lado 1: 4
# Lado 2: 2
# Lado 3: 3
# Escaleno

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Punto 15 - Si ternario
a = int(input("Lado 1: "))
b = int(input("Lado 2: "))
c = int(input("Lado 3: "))

print("No forman triángulo" if a+b<=c or a+c<=b or b+c<=a else "Equilátero" if a==b and b==c else "Isósceles" if a==b or a==c or b==c else "Escaleno")
# Out:
# Lado 1: 7
# Lado 2: 3
# Lado 3: 4
# No forman triángulo

# %% [markdown]
# ![image.png](data:image/png;base64,...)
